# %%
from nrc import *
import pandas as pd
import os.path
from os import path
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# constants and setup
FILENAME = 'data/svt_news.txt'
FILTERS = set(stopwords.words('swedish')) | set(string.punctuation) | {'--', '“', '”', '’'}

sentiments = ['negative', 'positive']
emotions = ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust']

lexicon = load_translated_lexicon('data/NRC-lexicon-sv.txt')
# Out:
# ...Loading translated NRC lexicon.

# %%
# get token vectors
token_vectors = get_token_vectors_from_text(FILENAME, lexicon, FILTERS)

# filter out token_vectors with less than sum of 50
token_vectors = {
    t: v for (t, v) in token_vectors.items() if v.sum() > 50
}

# create emotion vectors
emotion_vectors = {
    t: np.concatenate([v[:5], v[7:]]) for (t, v) in token_vectors.items()
}

# create sentiment vectors
sentiment_vectors = {
    t: v[5:7] for (t, v) in token_vectors.items()
}

normalize_token_vectors(emotion_vectors)
normalize_token_vectors(sentiment_vectors)

emotion_df = pd.DataFrame(data=emotion_vectors.values(), index=emotion_vectors.keys(), columns=emotions)
sentiment_df = pd.DataFrame(data=sentiment_vectors.values(), index=sentiment_vectors.keys(), columns=sentiments)

# convert index into column with name "word"
sentiment_df.reset_index(inplace=True)
sentiment_df = sentiment_df.rename(columns = {'index':'word'})

emotion_df.reset_index(inplace=True)
emotion_df = emotion_df.rename(columns = {'index':'word'})
# Out:
# ...Loading data from data/svt_news.txt.
# ...Normalizing token vectors.
# ...Normalizing token vectors.

# %%
# view first columns
sentiment_df.head()
# Out:
#           word  negative  positive
# 0      danmark  0.381818  0.618182
# 1         stor  0.341176  0.658824
# 2          del  0.414894  0.585106
# 3      bekämpa  0.625000  0.375000
# 4  spridningen  0.782609  0.217391

# %%
# view first columns
emotion_df.head()
# Out:
#           word     anger  anticipation   disgust      fear       joy  \
# 0      danmark  0.102719      0.201410  0.079557  0.169184  0.083585
# 1         stor  0.135135      0.117117  0.054054  0.162162  0.027027
# 2          del  0.118421      0.164474  0.072368  0.184211  0.078947
# 3      bekämpa  0.232558      0.046512  0.093023  0.279070  0.000000
# 4  spridningen  0.137931      0.275862  0.103448  0.206897  0.000000
#
#     sadness  surprise     trust
# 0  0.139980  0.055388  0.168177
# 1  0.189189  0.045045  0.270270
# 2  0.171053  0.065789  0.144737
# 3  0.116279  0.000000  0.232558
# 4  0.206897  0.000000  0.068966

# %%
queries = ['danmark', 'dansk', 'danskar', 'danska', 'danskarna']

danish_sent = sentiment_df[sentiment_df['word'].isin(queries)]

danish_sent
# Out:
#           word  negative  positive
# 0      danmark  0.381818  0.618182
# 46      danska  0.386943  0.613057
# 119    danskar  0.513514  0.486486
# 168      dansk  0.349515  0.650485
# 545  danskarna  0.384615  0.615385

# %%
danish_em = emotion_df[emotion_df['word'].isin(queries)]

danish_em
# Out:
#           word     anger  anticipation   disgust      fear       joy  \
# 0      danmark  0.102719      0.201410  0.079557  0.169184  0.083585
# 46      danska  0.123469      0.138776  0.107143  0.159184  0.085714
# 119    danskar  0.122066      0.136150  0.103286  0.183099  0.070423
# 168      dansk  0.130435      0.144928  0.123188  0.130435  0.086957
# 545  danskarna  0.113402      0.144330  0.051546  0.195876  0.051546
#
#       sadness  surprise     trust
# 0    0.139980  0.055388  0.168177
# 46   0.147959  0.033673  0.204082
# 119  0.178404  0.042254  0.164319
# 168  0.173913  0.021739  0.188406
# 545  0.154639  0.000000  0.288660

# %%
fig = px.bar(danish_sent, y='positive', color='word', x='word', range_y=[0, 1] )

fig.add_hline(y=0.5)

fig.show()
# Out:
# <div>                            <div id="62ebf6c7-37b5-49d0-933a-d47f99fcfa05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62ebf6c7-37b5-49d0-933a-d47f99fcfa05")) {                    Plotly.newPlot(                        "62ebf6c7-37b5-49d0-933a-d47f99fcfa05",                        [{"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>positive=%{y}<extra></extra>", "legendgroup": "danmark", "marker": {"color": "#636efa"}, "name": "danmark", "offsetgroup": "danmark", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danmark"], "xaxis": "x", "y": [0.6181818181818182], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>positive=%{y}<extra></extra>", "legendgroup": "danska", "marker": {"color": "#EF553B"}, "name": "danska", "offsetgroup": "danska", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danska"], "xaxis": "x", "y": [0.6130573248407644], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>positive=%{y}<extra></extra>", "legendgroup": "danskar", "marker": {"color": "#00cc96"}, "name": "danskar", "offsetgroup": "danskar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danskar"], "xaxis": "x", "y": [0.4864864864864865], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>positive=%{y}<extra></extra>", "legendgroup": "dansk", "marker": {"color": "#ab63fa"}, "name": "dansk", "offsetgroup": "dansk", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["dansk"], "xaxis": "x", "y": [0.6504854368932039], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>positive=%{y}<extra></extra>", "legendgroup": "danskarna", "marker": {"color": "#FFA15A"}, "name": "danskarna", "offsetgroup": "danskarna", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danskarna"], "xaxis": "x", "y": [0.6153846153846154], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "word"}, "tracegroupgap": 0}, "margin": {"t": 60}, "shapes": [{"type": "line", "x0": 0, "x1": 1, "xref": "x domain", "y0": 0.5, "y1": 0.5, "yref": "y"}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]] ...

# %%
fig = px.bar(danish_em, y='anger', color='word', x='word', range_y=[0, 1] )

fig.add_hline(y=0.5)

fig.show()
# Out:
# <div>                            <div id="43e3069c-1632-4fe5-a192-07d338faf4f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43e3069c-1632-4fe5-a192-07d338faf4f5")) {                    Plotly.newPlot(                        "43e3069c-1632-4fe5-a192-07d338faf4f5",                        [{"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>anger=%{y}<extra></extra>", "legendgroup": "danmark", "marker": {"color": "#636efa"}, "name": "danmark", "offsetgroup": "danmark", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danmark"], "xaxis": "x", "y": [0.1027190332326284], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>anger=%{y}<extra></extra>", "legendgroup": "danska", "marker": {"color": "#EF553B"}, "name": "danska", "offsetgroup": "danska", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danska"], "xaxis": "x", "y": [0.12346938775510204], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>anger=%{y}<extra></extra>", "legendgroup": "danskar", "marker": {"color": "#00cc96"}, "name": "danskar", "offsetgroup": "danskar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danskar"], "xaxis": "x", "y": [0.12206572769953052], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>anger=%{y}<extra></extra>", "legendgroup": "dansk", "marker": {"color": "#ab63fa"}, "name": "dansk", "offsetgroup": "dansk", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["dansk"], "xaxis": "x", "y": [0.13043478260869565], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>anger=%{y}<extra></extra>", "legendgroup": "danskarna", "marker": {"color": "#FFA15A"}, "name": "danskarna", "offsetgroup": "danskarna", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danskarna"], "xaxis": "x", "y": [0.1134020618556701], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "word"}, "tracegroupgap": 0}, "margin": {"t": 60}, "shapes": [{"type": "line", "x0": 0, "x1": 1, "xref": "x domain", "y0": 0.5, "y1": 0.5, "yref": "y"}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "h ...

# %%
danish_words = ['danmark', 'dansk', 'danskar', 'danska', 'danskarna']
swedish_words = ['sverige', 'svensk', 'svenskar', 'svenska', 'svenskarna']

# add nordic column
sentiment_df['nordic'] = ['d' if x in danish_words else 's' if x in swedish_words else 'n' for x in sentiment_df['word']]
emotion_df['nordic'] = ['d' if x in danish_words else 's' if x in swedish_words else 'n' for x in emotion_df['word']]

nordic_sentiments = sentiment_df.loc[(sentiment_df['nordic'] == 'd') | (sentiment_df['nordic'] == 's')]
nordic_emotions = emotion_df.loc[(emotion_df['nordic'] == 'd') | (emotion_df['nordic'] == 's')]

nordic_sentiments.head()
nordic_emotions.head()
# Out:
#         word     anger  anticipation   disgust      fear       joy   sadness  \
# 0    danmark  0.102719      0.201410  0.079557  0.169184  0.083585  0.139980
# 46    danska  0.123469      0.138776  0.107143  0.159184  0.085714  0.147959
# 119  danskar  0.122066      0.136150  0.103286  0.183099  0.070423  0.178404
# 122   svensk  0.000000      0.277778  0.066667  0.177778  0.066667  0.122222
# 125  sverige  0.114929      0.175355  0.091232  0.186019  0.061611  0.181280
#
#      surprise     trust nordic
# 0    0.055388  0.168177      d
# 46   0.033673  0.204082      d
# 119  0.042254  0.164319      d
# 122  0.033333  0.255556      s
# 125  0.039100  0.150474      s

# %%
fig = px.bar(nordic_sentiments, y='positive', color='nordic', x='word', range_y=[0, 1])
fig.add_hline(y=0.5)
fig.show()
# Out:
# <div>                            <div id="9123e6d6-9c83-4b0c-a7fc-d392f155f5a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9123e6d6-9c83-4b0c-a7fc-d392f155f5a8")) {                    Plotly.newPlot(                        "9123e6d6-9c83-4b0c-a7fc-d392f155f5a8",                        [{"alignmentgroup": "True", "hovertemplate": "nordic=d<br>word=%{x}<br>positive=%{y}<extra></extra>", "legendgroup": "d", "marker": {"color": "#636efa"}, "name": "d", "offsetgroup": "d", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danmark", "danska", "danskar", "dansk", "danskarna"], "xaxis": "x", "y": [0.6181818181818182, 0.6130573248407644, 0.4864864864864865, 0.6504854368932039, 0.6153846153846154], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "nordic=s<br>word=%{x}<br>positive=%{y}<extra></extra>", "legendgroup": "s", "marker": {"color": "#EF553B"}, "name": "s", "offsetgroup": "s", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["svensk", "sverige", "svenska", "svenskarna", "svenskar"], "xaxis": "x", "y": [0.6973684210526315, 0.5602968460111317, 0.6810344827586207, 0.6451612903225806, 0.7428571428571429], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "nordic"}, "tracegroupgap": 0}, "margin": {"t": 60}, "shapes": [{"type": "line", "x0": 0, "x1": 1, "xref": "x domain", "y0": 0.5, "y1": 0.5, "yref": "y"}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.66666666 ...

# %%
# ['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust']

# %%
emotion = 'trust'

fig = px.bar(nordic_emotions.sort_values(by=[emotion], ascending=False), y=emotion, color='nordic', x='word', range_y=[0, 1])
fig.add_hline(y=0.125)
fig.show()
# Out:
# <div>                            <div id="56526e2e-945a-451a-8e87-81318cf888e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56526e2e-945a-451a-8e87-81318cf888e1")) {                    Plotly.newPlot(                        "56526e2e-945a-451a-8e87-81318cf888e1",                        [{"alignmentgroup": "True", "hovertemplate": "nordic=s<br>word=%{x}<br>trust=%{y}<extra></extra>", "legendgroup": "s", "marker": {"color": "#636efa"}, "name": "s", "offsetgroup": "s", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["svenskar", "svensk", "svenska", "sverige", "svenskarna"], "xaxis": "x", "y": [0.35294117647058826, 0.25555555555555554, 0.20359281437125748, 0.1504739336492891, 0.14893617021276595], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "nordic=d<br>word=%{x}<br>trust=%{y}<extra></extra>", "legendgroup": "d", "marker": {"color": "#EF553B"}, "name": "d", "offsetgroup": "d", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["danskarna", "danska", "dansk", "danmark", "danskar"], "xaxis": "x", "y": [0.28865979381443296, 0.20408163265306123, 0.18840579710144928, 0.16817724068479356, 0.1643192488262911], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "nordic"}, "tracegroupgap": 0}, "margin": {"t": 60}, "shapes": [{"type": "line", "x0": 0, "x1": 1, "xref": "x domain", "y0": 0.125, "y1": 0.125, "yref": "y"}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.66 ...

# %%
emotion = 'joy'

sortaro = emotion_df.sort_values(by=[emotion], ascending=False).head(5)

#sortaro['joy'].plot(kind='bar')
fig = px.bar(
        sortaro, y=emotion, color='word', x='word' 
      )
fig.show()
# Out:
# <div>                            <div id="728fe8d6-73cb-4b4b-9984-208cf15f8e64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("728fe8d6-73cb-4b4b-9984-208cf15f8e64")) {                    Plotly.newPlot(                        "728fe8d6-73cb-4b4b-9984-208cf15f8e64",                        [{"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>joy=%{y}<extra></extra>", "legendgroup": "ecstasy", "marker": {"color": "#636efa"}, "name": "ecstasy", "offsetgroup": "ecstasy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["ecstasy"], "xaxis": "x", "y": [0.29213483146067415], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>joy=%{y}<extra></extra>", "legendgroup": "enjoy", "marker": {"color": "#EF553B"}, "name": "enjoy", "offsetgroup": "enjoy", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["enjoy"], "xaxis": "x", "y": [0.2894736842105263], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>joy=%{y}<extra></extra>", "legendgroup": "aspiring", "marker": {"color": "#00cc96"}, "name": "aspiring", "offsetgroup": "aspiring", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["aspiring"], "xaxis": "x", "y": [0.2894736842105263], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>joy=%{y}<extra></extra>", "legendgroup": "glad", "marker": {"color": "#ab63fa"}, "name": "glad", "offsetgroup": "glad", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["glad"], "xaxis": "x", "y": [0.2867647058823529], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "word=%{x}<br>joy=%{y}<extra></extra>", "legendgroup": "apply", "marker": {"color": "#FFA15A"}, "name": "apply", "offsetgroup": "apply", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["apply"], "xaxis": "x", "y": [0.2857142857142857], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "word"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f" ...

# %%
# 'anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness', 'surprise', 'trust'

emotion = 'fear'

gender_emotion = emotion_df.loc[(emotion_df['gender'] == 'm') | (emotion_df['gender'] == 'f')]

filters = ['ordinary', 'bag', 'cat', 'dog', 'stiff', 'wolf', 'tom', 'town']

for filt in filters:
    gender_emotion = gender_emotion[gender_emotion['word'] != filt]
    
sortaro = gender_emotion.sort_values(by=[emotion], ascending=False)

fig = px.bar(
        sortaro, y=emotion, color='gender', x='word' 
      )
fig.show()
# Out:
# <div>                            <div id="5c2241a0-8894-4a9d-9054-0f7b0a6b40b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c2241a0-8894-4a9d-9054-0f7b0a6b40b8")) {                    Plotly.newPlot(                        "5c2241a0-8894-4a9d-9054-0f7b0a6b40b8",                        [{"alignmentgroup": "True", "hovertemplate": "gender=m<br>word=%{x}<br>fear=%{y}<extra></extra>", "legendgroup": "m", "marker": {"color": "#636efa"}, "name": "m", "offsetgroup": "m", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["sir", "men", "man", "gentleman", "englishman", "emperor", "fellow", "boy", "brother", "lord", "gentlemen", "father", "son", "king", "husband"], "xaxis": "x", "y": [0.19254658385093168, 0.1782178217821782, 0.1674641148325359, 0.1643835616438356, 0.14772727272727273, 0.14583333333333334, 0.143646408839779, 0.13392857142857142, 0.1267605633802817, 0.11814345991561181, 0.11764705882352941, 0.09803921568627451, 0.06716417910447761, 0.06428571428571428, 0.0625], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "gender=f<br>word=%{x}<br>fear=%{y}<extra></extra>", "legendgroup": "f", "marker": {"color": "#EF553B"}, "name": "f", "offsetgroup": "f", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["broad", "mother", "women", "widow"], "xaxis": "x", "y": [0.1320754716981132, 0.07432432432432433, 0.06779661016949153, 0.04580152671755725], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "gender"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222 ...

# %%
get_similarity(emotion_vectors, 'woman', 'bloom')
# Out:
# woman not in token database,
# bloom not in token database,

# %%
emotion_df.loc[['man', 'woman', 'boy', 'girl']]
# Out:
# /Users/fluffy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
#
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#           anger  anticipation   disgust      fear       joy   sadness  \
# man    0.109516      0.158958  0.056885  0.167464  0.129718  0.099947
# woman       NaN           NaN       NaN       NaN       NaN       NaN
# boy    0.075893      0.120536  0.191964  0.133929  0.111607  0.116071
# girl        NaN           NaN       NaN       NaN       NaN       NaN
#
#        surprise     trust
# man    0.076555  0.200957
# woman       NaN       NaN
# boy    0.071429  0.178571
# girl        NaN       NaN

# %%
sentiment_df.loc[['man', 'woman', 'boy', 'girl']]
# Out:
# /Users/fluffy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
#
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#        negative  positive
# man    0.414013  0.585987
# woman       NaN       NaN
# boy    0.519737  0.480263
# girl        NaN       NaN

# %%
get_most_similar(emotion_vectors, 'girl', 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-adcbe81212e1> in <module>
# ----> 1 get_most_similar(emotion_vectors, 'girl', 10)
#
# NameError: name 'get_most_similar' is not defined

# %%
sentiment_df.sort_values(by=['positive'], ascending=False)
# Out:
#            negative  positive
# romantic   0.052632  0.947368
# prince     0.055556  0.944444
# birth      0.058824  0.941176
# service    0.066667  0.933333
# pray       0.100000  0.900000
# ...             ...       ...
# omen       0.888889  0.111111
# dens       0.916667  0.083333
# destroyed  0.928571  0.071429
# agony      0.933333  0.066667
# shot       0.961538  0.038462
#
# [1051 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

emotion = 'fear'

e_index = {'anger': 0, 'anticipation': 1, 'disgust': 2, 'fear': 3, 'joy': 4, 'sadness': 5, 'surprise': 6, 'trust': 7}
e = e_index[emotion]

# trust versus positivity
x_values = [v[e] for v in emotion_vectors.values()]
y_values = [v[1] for v in sentiment_vectors.values()]

plt.title(f'positivity vs. {emotion}')
plt.xlabel(emotion)
plt.ylabel('positivity')

plt.scatter(x_values, y_values, s=5)

# %%
emotion1 = 'anger'
emotion2 = 'sadness'

e_index = {'anger': 0, 'anticipation': 1, 'disgust': 2, 'fear': 3, 'joy': 4, 'sadness': 5, 'surprise': 6, 'trust': 7}

e1 = e_index[emotion1]
e2 = e_index[emotion2]

# trust versus positivity
x_values = [v[e1] for v in emotion_vectors.values()]
y_values = [v[e2] for v in emotion_vectors.values()]

plt.title(f'{emotion1} vs. {emotion2}')
plt.xlabel(emotion1)
plt.ylabel(emotion2)

plt.scatter(x_values, y_values, s=5)

# %%
from collections import Counter

# get most common words in book
# open and read the contents of a file
with open(FILENAME) as f:
    data = f.read()

# clean the data
data = data.replace('_', '') # note to self: italics words
data = data.replace('\n', ' ')
data = data.replace('"', '')
data = data.lower()

words = word_tokenize(data)
words = [w for w in words if w not in FILTERS]

word_collection = Counter(words)

# %%
word_collection.most_common(10)
# Out:
# [('one', 433),
#  ("n't", 418),
#  ('dorian', 414),
#  ('would', 312),
#  ('said', 262),
#  ("'s", 259),
#  ('lord', 248),
#  ('henry', 236),
#  ('life', 229),
#  ('like', 210)]

# %%
labels = e_index.keys()
plt.pie(emotion_vectors['girl'], labels=labels, autopct='%1.1f%%')
plt.show()

# %%
plt.pie(emotion_vectors['boy'], labels=labels, autopct='%1.1f%%')
plt.show()
